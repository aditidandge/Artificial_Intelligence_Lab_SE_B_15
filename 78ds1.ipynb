# %% [markdown]
# <a href="https://colab.research.google.com/github/aditidandge/Artificial_Intelligence_Lab_SE_B_15/blob/master/78ds1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#WAP to compute factorial of a given number

# %%
num = int(input("Enter a number: "))

factorial = 1

if num < 0:
    print("Factorial does not exist for negative numbers.")
elif num == 0:
    print("Factorial of 0 is 1.")
else:
    for i in range(1, num + 1):
        factorial *= i
    print("Factorial of", num, "is", factorial)
# Out:
# Enter a number: 25
# Factorial of 25 is 15511210043330985984000000

# %%
num = int(input("Enter a number to display its multiplication table: "))

print(f"Multiplication Table for {num}:")
for i in range(1, 11):
    print(f"{num} x {i} = {num * i}")
# Out:
# Enter a number to display its multiplication table: 23
# Multiplication Table for 23:
# 23 x 1 = 23
# 23 x 2 = 46
# 23 x 3 = 69
# 23 x 4 = 92
# 23 x 5 = 115
# 23 x 6 = 138
# 23 x 7 = 161
# 23 x 8 = 184
# 23 x 9 = 207
# 23 x 10 = 230

# %%
num = int(input("Enter a number: "))

if (num % 2) == 0:
   print(f"{num} is an even number")
else:
   print(f"{num} is an odd number")
# Out:
# Enter a number: 7
# 7 is an odd number

# %%
num_str = input("Enter a number: ")

if num_str == num_str[::-1]:
    print(f"{num_str} is a palindrome.")
else:
    print(f"{num_str} is not a palindrome.")
# Out:
# Enter a number: 69
# 69 is not a palindrome.

# %% [markdown]
# # Task
# To begin, please describe a simple decision-making scenario for the expert system. For instance, you could propose a scenario like "Should I wear a jacket today?". For your chosen scenario, please specify:
# 1.  **Inputs (facts)**: What information would the system need to make a decision?
# 2.  **Desired Output (decision)**: What is the final decision the system should provide?
# 3.  **Rules**: What are the conditions that link the inputs to the output?

# %% [markdown]
# ## Understand Expert System Requirements
#
# ### Subtask:
# Describe a simple decision-making scenario for an expert system, including its inputs, desired output, and the rules linking them.

# %% [markdown]
# ## Expert System Scenario: Book Recommendation
#
# ### 1. Scenario: Book Recommendation
# **Problem:** A user wants to find a new book to read based on their preferences.
#
# ### 2. Inputs (Facts):
# *   **User's Preferred Genre:** (e.g., 'Fantasy', 'Science Fiction', 'Mystery', 'Thriller', 'Romance')
# *   **User's Preferred Reading Level:** (e.g., 'Beginner', 'Intermediate', 'Advanced')
# *   **User's Availability:** (e.g., 'Short Reads' for less than 200 pages, 'Medium Reads' for 200-500 pages, 'Long Reads' for more than 500 pages)
#
# ### 3. Desired Output (Decision):
# *   **Recommended Book Title:** (e.g., 'The Hobbit', 'Dune', 'Gone Girl')
# *   **Recommendation Type:** (e.g., 'Strong Recommendation', 'Mild Recommendation', 'No Recommendation')
#
# ### 4. Rules:
# *   **Rule 1: Strong Recommendation for Fantasy Beginner**
#     IF User's Preferred Genre IS 'Fantasy'
#     AND User's Preferred Reading Level IS 'Beginner'
#     AND User's Availability IS 'Medium Reads'
#     THEN Recommend 'The Hobbit' WITH Recommendation Type 'Strong Recommendation'.
#
# *   **Rule 2: Strong Recommendation for Sci-Fi Advanced**
#     IF User's Preferred Genre IS 'Science Fiction'
#     AND User's Preferred Reading Level IS 'Advanced'
#     AND User's Availability IS 'Long Reads'
#     THEN Recommend 'Dune' WITH Recommendation Type 'Strong Recommendation'.
#
# *   **Rule 3: Mild Recommendation for Mystery Intermediate**
#     IF User's Preferred Genre IS 'Mystery'
#     AND User's Preferred Reading Level IS 'Intermediate'
#     AND User's Availability IS 'Medium Reads'
#     THEN Recommend 'Gone Girl' WITH Recommendation Type 'Mild Recommendation'.
#
# *   **Rule 4: No Recommendation**
#     IF no other rules are met
#     THEN Output 'No suitable book found' WITH Recommendation Type 'No Recommendation'.

# %% [markdown]
# ## Design Knowledge Base
#
# ### Subtask:
# Design a basic knowledge base structure to store the rules identified in the previous step, using Python data structures.

# %% [markdown]
# **Reasoning**:
# To design a basic knowledge base structure, I will create a Python list of dictionaries, where each dictionary represents a rule with 'conditions' and 'actions' keys, as specified in the instructions. This directly addresses the first instruction.

# %%
knowledge_base = [
    {
        'conditions': {
            'genre': 'Fantasy',
            'reading_level': 'Beginner',
            'availability': 'High'
        },
        'actions': {
            'recommendation': 'The Hobbit',
            'recommendation_type': 'Strong Recommendation'
        }
    },
    {
        'conditions': {
            'genre': 'Science Fiction',
            'reading_level': 'Intermediate',
            'availability': 'Medium'
        },
        'actions': {
            'recommendation': 'Dune',
            'recommendation_type': 'Moderate Recommendation'
        }
    },
    {
        'conditions': {
            'genre': 'Mystery',
            'reading_level': 'Advanced',
            'availability': 'Low'
        },
        'actions': {
            'recommendation': 'Sherlock Holmes',
            'recommendation_type': 'Specific Recommendation'
        }
    },
    {
        'conditions': {},
        'actions': {
            'recommendation': 'No suitable recommendation found.',
            'recommendation_type': 'No Recommendation'
        }
    }
]

print("Knowledge base created successfully.")
# Out:
# Knowledge base created successfully.

# %% [markdown]
# **Reasoning**:
# The previous `knowledge_base` definition did not precisely match the rules outlined in the `Expert System Scenario: Book Recommendation` text cell. To adhere to the instructions to 'Ensure to include all four rules previously defined', I will redefine the `knowledge_base` to accurately reflect those rules.
